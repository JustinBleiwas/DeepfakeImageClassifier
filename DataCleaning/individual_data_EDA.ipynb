# %%
# Color comparison between real and fake images.

import os
import numpy as np
from PIL import Image

cleaned_path = "dataset_1_cleaned"
real_dir = os.path.join(cleaned_path, "real")
fake_dir = os.path.join(cleaned_path, "fake")

def compute_color_stats(folder):
    means = []
    stds = []

    files = [f for f in os.listdir(folder) if f.lower().endswith(".jpg")]

    for i, fname in enumerate(files):
        if i % 10000 == 0:
            print(f"Processed {i} images in {folder}...")

        img = Image.open(os.path.join(folder, fname)).convert("RGB")
        arr = np.array(img) / 255.0  # normalize to [0,1]

        means.append(arr.mean(axis=(0,1)))
        stds.append(arr.std(axis=(0,1)))

    means = np.array(means)
    stds = np.array(stds)

    return means.mean(axis=0), stds.mean(axis=0)

real_mean, real_std = compute_color_stats(real_dir)
fake_mean, fake_std = compute_color_stats(fake_dir)

print("\n=== REAL ===")
print("Mean RGB:", real_mean)
print("Std RGB:", real_std)

print("\n=== FAKE ===")
print("Mean RGB:", fake_mean)
print("Std RGB:", fake_std)
# Out:
# Processed 0 images in dataset_1_cleaned\real...
# Processed 10000 images in dataset_1_cleaned\real...
# Processed 20000 images in dataset_1_cleaned\real...
# Processed 0 images in dataset_1_cleaned\fake...
# Processed 10000 images in dataset_1_cleaned\fake...
# Processed 20000 images in dataset_1_cleaned\fake...
#
# === REAL ===
# Mean RGB: [0.52026528 0.42533899 0.38030437]
# Std RGB: [0.25246236 0.22657993 0.22372848]
#
# === FAKE ===
# Mean RGB: [0.47030001 0.40848903 0.38178443]
# Std RGB: [0.23700872 0.21752416 0.20646516]

# %%
# Color comparison between real and fake images.

import os
import numpy as np
from PIL import Image

cleaned_path = "dataset_2_cleaned"
real_dir = os.path.join(cleaned_path, "real")
fake_dir = os.path.join(cleaned_path, "fake")

def compute_color_stats(folder):
    means = []
    stds = []

    files = [f for f in os.listdir(folder) if f.lower().endswith(".jpg")]

    for i, fname in enumerate(files):
        if i % 10000 == 0:
            print(f"Processed {i} images in {folder}...")

        img = Image.open(os.path.join(folder, fname)).convert("RGB")
        arr = np.array(img) / 255.0  # normalize to [0,1]

        means.append(arr.mean(axis=(0,1)))
        stds.append(arr.std(axis=(0,1)))

    means = np.array(means)
    stds = np.array(stds)

    return means.mean(axis=0), stds.mean(axis=0)

real_mean, real_std = compute_color_stats(real_dir)
fake_mean, fake_std = compute_color_stats(fake_dir)

print("\n=== REAL ===")
print("Mean RGB:", real_mean)
print("Std RGB:", real_std)

print("\n=== FAKE ===")
print("Mean RGB:", fake_mean)
print("Std RGB:", fake_std)
# Out:
# Processed 0 images in dataset_2_cleaned\real...
# Processed 10000 images in dataset_2_cleaned\real...
# Processed 20000 images in dataset_2_cleaned\real...
# Processed 30000 images in dataset_2_cleaned\real...
# Processed 40000 images in dataset_2_cleaned\real...
# Processed 50000 images in dataset_2_cleaned\real...
# Processed 60000 images in dataset_2_cleaned\real...
# Processed 0 images in dataset_2_cleaned\fake...
# Processed 10000 images in dataset_2_cleaned\fake...
# Processed 20000 images in dataset_2_cleaned\fake...
# Processed 30000 images in dataset_2_cleaned\fake...
# Processed 40000 images in dataset_2_cleaned\fake...
# Processed 50000 images in dataset_2_cleaned\fake...
#
# === REAL ===
# Mean RGB: [0.51163522 0.42002649 0.37627459]
# Std RGB: [0.25025372 0.22581356 0.22228649]
#
# === FAKE ===
# Mean RGB: [0.51988021 0.42543724 0.38002325]
# Std RGB: [0.2454115  0.22043857 0.2182703 ]

# %%
# Color comparison between real and fake images.

import os
import numpy as np
from PIL import Image

cleaned_path = "dataset_3_cleaned"
real_dir = os.path.join(cleaned_path, "real")
fake_dir = os.path.join(cleaned_path, "fake")

def compute_color_stats(folder):
    means = []
    stds = []

    files = [f for f in os.listdir(folder) if f.lower().endswith(".jpg")]

    for i, fname in enumerate(files):
        if i % 10000 == 0:
            print(f"Processed {i} images in {folder}...")

        img = Image.open(os.path.join(folder, fname)).convert("RGB")
        arr = np.array(img) / 255.0  # normalize to [0,1]

        means.append(arr.mean(axis=(0,1)))
        stds.append(arr.std(axis=(0,1)))

    means = np.array(means)
    stds = np.array(stds)

    return means.mean(axis=0), stds.mean(axis=0)

real_mean, real_std = compute_color_stats(real_dir)
fake_mean, fake_std = compute_color_stats(fake_dir)

print("\n=== REAL ===")
print("Mean RGB:", real_mean)
print("Std RGB:", real_std)

print("\n=== FAKE ===")
print("Mean RGB:", fake_mean)
print("Std RGB:", fake_std)
# Out:
# Processed 0 images in dataset_3_cleaned\real...
# Processed 10000 images in dataset_3_cleaned\real...
# Processed 20000 images in dataset_3_cleaned\real...
# Processed 0 images in dataset_3_cleaned\fake...
# Processed 10000 images in dataset_3_cleaned\fake...
# Processed 20000 images in dataset_3_cleaned\fake...
# Processed 30000 images in dataset_3_cleaned\fake...
# Processed 40000 images in dataset_3_cleaned\fake...
# Processed 50000 images in dataset_3_cleaned\fake...
# Processed 60000 images in dataset_3_cleaned\fake...
# Processed 70000 images in dataset_3_cleaned\fake...
# Processed 80000 images in dataset_3_cleaned\fake...
# Processed 90000 images in dataset_3_cleaned\fake...
# Processed 100000 images in dataset_3_cleaned\fake...
# Processed 110000 images in dataset_3_cleaned\fake...
# Processed 120000 images in dataset_3_cleaned\fake...
# Processed 130000 images in dataset_3_cleaned\fake...
# Processed 140000 images in dataset_3_cleaned\fake...
# Processed 150000 images in dataset_3_cleaned\fake...
#
# === REAL ===
# Mean RGB: [0.4861264  0.3947464  0.37776832]
# Std RGB: [0.24168483 0.19981864 0.19959733]
#
# === FAKE ===
# Mean RGB: [0.47620128 0.38963582 0.37033736]
# Std RGB: [0.23626277 0.20007762 0.20096539]

# %%
# Color comparison between real and fake images.

import os
import numpy as np
from PIL import Image

cleaned_path = "test_dataset"
real_dir = os.path.join(cleaned_path, "real")
fake_dir = os.path.join(cleaned_path, "fake")

def compute_color_stats(folder):
    means = []
    stds = []

    files = [f for f in os.listdir(folder) if f.lower().endswith(".jpg")]

    for i, fname in enumerate(files):
        if i % 10000 == 0:
            print(f"Processed {i} images in {folder}...")

        img = Image.open(os.path.join(folder, fname)).convert("RGB")
        arr = np.array(img) / 255.0  # normalize to [0,1]

        means.append(arr.mean(axis=(0,1)))
        stds.append(arr.std(axis=(0,1)))

    means = np.array(means)
    stds = np.array(stds)

    return means.mean(axis=0), stds.mean(axis=0)

real_mean, real_std = compute_color_stats(real_dir)
fake_mean, fake_std = compute_color_stats(fake_dir)

print("\n=== REAL ===")
print("Mean RGB:", real_mean)
print("Std RGB:", real_std)

print("\n=== FAKE ===")
print("Mean RGB:", fake_mean)
print("Std RGB:", fake_std)
# Out:
# Processed 0 images in test_dataset\real...
# Processed 0 images in test_dataset\fake...
# Processed 10000 images in test_dataset\fake...
#
# === REAL ===
# Mean RGB: [0.49329232 0.40220979 0.36042206]
# Std RGB: [0.25740668 0.22813609 0.21997048]
#
# === FAKE ===
# Mean RGB: [0.4640765  0.39621835 0.36738954]
# Std RGB: [0.23700417 0.21018388 0.20649398]

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm

# Paths
real_dir = "dataset_1_cleaned/real"
fake_dir = "dataset_1_cleaned/fake"

def fft_magnitude(img):
    """Compute centered FFT magnitude for a grayscale image."""
    img_gray = np.array(img.convert("L"), dtype=np.float32) / 255.0
    fft = np.fft.fft2(img_gray)
    fft_shift = np.fft.fftshift(fft)
    magnitude = np.abs(fft_shift)
    return magnitude

def radial_profile(mag):
    """Compute radial average of FFT magnitude."""
    h, w = mag.shape
    cy, cx = h // 2, w // 2

    y, x = np.indices((h, w))
    r = np.sqrt((x - cx)**2 + (y - cy)**2)
    r = r.astype(np.int32)

    max_r = min(cx, cy)
    radial_mean = np.bincount(r.ravel(), mag.ravel()) / np.bincount(r.ravel())
    return radial_mean[:max_r]

def process_folder(folder):
    profiles = []
    files = os.listdir(folder)

    for fname in tqdm(files, desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        mag = fft_magnitude(img)
        prof = radial_profile(mag)
        profiles.append(prof)

    # Pad to same length
    max_len = max(len(p) for p in profiles)
    padded = np.array([np.pad(p, (0, max_len - len(p)), mode='edge') for p in profiles])

    return padded

# Process real and fake
real_profiles = process_folder(real_dir)
fake_profiles = process_folder(fake_dir)

# Compute class averages
real_mean = real_profiles.mean(axis=0)
fake_mean = fake_profiles.mean(axis=0)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(real_mean, label="Real", linewidth=2)
plt.plot(fake_mean, label="Fake", linewidth=2)
plt.title("Average Log FFT Radial Magnitude Profile (Real vs Fake)")
plt.xlabel("Radial Frequency")
plt.ylabel("Magnitude")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing dataset_1_cleaned/real: 100%|██████████| 28475/28475 [03:11<00:00, 148.68it/s]
# Processing dataset_1_cleaned/fake: 100%|██████████| 28596/28596 [03:17<00:00, 145.08it/s]

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm

# Paths
real_dir = "dataset_2_cleaned/real"
fake_dir = "dataset_2_cleaned/fake"

def fft_magnitude(img):
    """Compute centered FFT magnitude for a grayscale image."""
    img_gray = np.array(img.convert("L"), dtype=np.float32) / 255.0
    fft = np.fft.fft2(img_gray)
    fft_shift = np.fft.fftshift(fft)
    magnitude = np.abs(fft_shift)
    return magnitude

def radial_profile(mag):
    """Compute radial average of FFT magnitude."""
    h, w = mag.shape
    cy, cx = h // 2, w // 2

    y, x = np.indices((h, w))
    r = np.sqrt((x - cx)**2 + (y - cy)**2)
    r = r.astype(np.int32)

    max_r = min(cx, cy)
    radial_mean = np.bincount(r.ravel(), mag.ravel()) / np.bincount(r.ravel())
    return radial_mean[:max_r]

def process_folder(folder):
    profiles = []
    files = os.listdir(folder)

    for fname in tqdm(files, desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        mag = fft_magnitude(img)
        prof = radial_profile(mag)
        profiles.append(prof)

    # Pad to same length
    max_len = max(len(p) for p in profiles)
    padded = np.array([np.pad(p, (0, max_len - len(p)), mode='edge') for p in profiles])

    return padded

# Process real and fake
real_profiles = process_folder(real_dir)
fake_profiles = process_folder(fake_dir)

# Compute class averages
real_mean = real_profiles.mean(axis=0)
fake_mean = fake_profiles.mean(axis=0)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(real_mean, label="Real", linewidth=2)
plt.plot(fake_mean, label="Fake", linewidth=2)
plt.title("Average Log FFT Radial Magnitude Profile (Real vs Fake)")
plt.xlabel("Radial Frequency")
plt.ylabel("Magnitude")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing dataset_2_cleaned/real: 100%|██████████| 60192/60192 [06:57<00:00, 144.28it/s]
# Processing dataset_2_cleaned/fake: 100%|██████████| 51991/51991 [06:01<00:00, 143.68it/s]

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm

# Paths
real_dir = "dataset_3_cleaned/real"
fake_dir = "dataset_3_cleaned/fake"

def fft_magnitude(img):
    """Compute centered FFT magnitude for a grayscale image."""
    img_gray = np.array(img.convert("L"), dtype=np.float32) / 255.0
    fft = np.fft.fft2(img_gray)
    fft_shift = np.fft.fftshift(fft)
    magnitude = np.abs(fft_shift)
    return magnitude

def radial_profile(mag):
    """Compute radial average of FFT magnitude."""
    h, w = mag.shape
    cy, cx = h // 2, w // 2

    y, x = np.indices((h, w))
    r = np.sqrt((x - cx)**2 + (y - cy)**2)
    r = r.astype(np.int32)

    max_r = min(cx, cy)
    radial_mean = np.bincount(r.ravel(), mag.ravel()) / np.bincount(r.ravel())
    return radial_mean[:max_r]

def process_folder(folder):
    profiles = []
    files = os.listdir(folder)

    for fname in tqdm(files, desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        mag = fft_magnitude(img)
        prof = radial_profile(mag)
        profiles.append(prof)

    # Pad to same length
    max_len = max(len(p) for p in profiles)
    padded = np.array([np.pad(p, (0, max_len - len(p)), mode='edge') for p in profiles])

    return padded

# Process real and fake
real_profiles = process_folder(real_dir)
fake_profiles = process_folder(fake_dir)

# Compute class averages
real_mean = real_profiles.mean(axis=0)
fake_mean = fake_profiles.mean(axis=0)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(real_mean, label="Real", linewidth=2)
plt.plot(fake_mean, label="Fake", linewidth=2)
plt.title("Average Log FFT Radial Magnitude Profile (Real vs Fake)")
plt.xlabel("Radial Frequency")
plt.ylabel("Magnitude")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing dataset_3_cleaned/real: 100%|██████████| 26444/26444 [02:46<00:00, 158.93it/s]
# Processing dataset_3_cleaned/fake: 100%|██████████| 155802/155802 [16:00<00:00, 162.25it/s]

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm

# Paths
real_dir = "test_dataset/real"
fake_dir = "test_dataset/fake"

def fft_magnitude(img):
    """Compute centered FFT magnitude for a grayscale image."""
    img_gray = np.array(img.convert("L"), dtype=np.float32) / 255.0
    fft = np.fft.fft2(img_gray)
    fft_shift = np.fft.fftshift(fft)
    magnitude = np.abs(fft_shift)
    return magnitude

def radial_profile(mag):
    """Compute radial average of FFT magnitude."""
    h, w = mag.shape
    cy, cx = h // 2, w // 2

    y, x = np.indices((h, w))
    r = np.sqrt((x - cx)**2 + (y - cy)**2)
    r = r.astype(np.int32)

    max_r = min(cx, cy)
    radial_mean = np.bincount(r.ravel(), mag.ravel()) / np.bincount(r.ravel())
    return radial_mean[:max_r]

def process_folder(folder):
    profiles = []
    files = os.listdir(folder)

    for fname in tqdm(files, desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        mag = fft_magnitude(img)
        prof = radial_profile(mag)
        profiles.append(prof)

    # Pad to same length
    max_len = max(len(p) for p in profiles)
    padded = np.array([np.pad(p, (0, max_len - len(p)), mode='edge') for p in profiles])

    return padded

# Process real and fake
real_profiles = process_folder(real_dir)
fake_profiles = process_folder(fake_dir)

# Compute class averages
real_mean = real_profiles.mean(axis=0)
fake_mean = fake_profiles.mean(axis=0)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(real_mean, label="Real", linewidth=2)
plt.plot(fake_mean, label="Fake", linewidth=2)
plt.title("Average Log FFT Radial Magnitude Profile (Real vs Fake)")
plt.xlabel("Radial Frequency")
plt.ylabel("Magnitude")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing test_dataset/real: 100%|██████████| 5890/5890 [00:31<00:00, 186.65it/s]
# Processing test_dataset/fake: 100%|██████████| 12234/12234 [01:06<00:00, 183.39it/s]

# %%
import os
import numpy as np
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
from scipy.fftpack import dct

real_dir = "dataset_1_cleaned/real"
fake_dir = "dataset_1_cleaned/fake"

def block_dct(img, block=8):
    """Compute 8×8 block DCT magnitudes for a grayscale image."""
    arr = np.array(img.convert("L"), dtype=np.float32)
    h, w = arr.shape

    # ensure divisible by block size
    h = h - (h % block)
    w = w - (w % block)
    arr = arr[:h, :w]

    coeffs = []

    for i in range(0, h, block):
        for j in range(0, w, block):
            patch = arr[i:i+block, j:j+block]
            d = dct(dct(patch.T, norm='ortho').T, norm='ortho')
            coeffs.append(np.abs(d))

    coeffs = np.stack(coeffs)  # shape: (num_blocks, 8, 8)
    return coeffs

def process_folder(folder):
    all_coeffs = []

    for fname in tqdm(os.listdir(folder), desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        c = block_dct(img)
        all_coeffs.append(c.mean(axis=0))  # average over blocks

    return np.stack(all_coeffs)  # shape: (num_images, 8, 8)

real_dct = process_folder(real_dir)
fake_dct = process_folder(fake_dir)

# average over images
real_mean = real_dct.mean(axis=0).flatten()
fake_mean = fake_dct.mean(axis=0).flatten()

plt.figure(figsize=(10,6))
plt.plot(real_mean, label="Real", linewidth=2)
plt.plot(fake_mean, label="Fake", linewidth=2)
plt.title("Average Log DCT Coefficient Magnitudes (Real vs Fake)")
plt.xlabel("Coefficient Index (0–63)")
plt.ylabel("Magnitude")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing dataset_1_cleaned/real: 100%|██████████| 28475/28475 [09:33<00:00, 49.65it/s]
# Processing dataset_1_cleaned/fake: 100%|██████████| 28596/28596 [09:34<00:00, 49.79it/s]

# %%
import os
import numpy as np
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
from scipy.fftpack import dct

real_dir = "dataset_2_cleaned/real"
fake_dir = "dataset_2_cleaned/fake"

def block_dct(img, block=8):
    """Compute 8×8 block DCT magnitudes for a grayscale image."""
    arr = np.array(img.convert("L"), dtype=np.float32)
    h, w = arr.shape

    # ensure divisible by block size
    h = h - (h % block)
    w = w - (w % block)
    arr = arr[:h, :w]

    coeffs = []

    for i in range(0, h, block):
        for j in range(0, w, block):
            patch = arr[i:i+block, j:j+block]
            d = dct(dct(patch.T, norm='ortho').T, norm='ortho')
            coeffs.append(np.abs(d))

    coeffs = np.stack(coeffs)  # shape: (num_blocks, 8, 8)
    return coeffs

def process_folder(folder):
    all_coeffs = []

    for fname in tqdm(os.listdir(folder), desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        c = block_dct(img)
        all_coeffs.append(c.mean(axis=0))  # average over blocks

    return np.stack(all_coeffs)  # shape: (num_images, 8, 8)

real_dct = process_folder(real_dir)
fake_dct = process_folder(fake_dir)

# average over images
real_mean = real_dct.mean(axis=0).flatten()
fake_mean = fake_dct.mean(axis=0).flatten()

plt.figure(figsize=(10,6))
plt.plot(real_mean, label="Real", linewidth=2)
plt.plot(fake_mean, label="Fake", linewidth=2)
plt.title("Average Log DCT Coefficient Magnitudes (Real vs Fake)")
plt.xlabel("Coefficient Index (0–63)")
plt.ylabel("Magnitude")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing dataset_2_cleaned/real: 100%|██████████| 60192/60192 [21:15<00:00, 47.19it/s]
# Processing dataset_2_cleaned/fake: 100%|██████████| 51991/51991 [16:55<00:00, 51.22it/s]

# %%
import os
import numpy as np
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
from scipy.fftpack import dct

real_dir = "dataset_3_cleaned/real"
fake_dir = "dataset_3_cleaned/fake"

def block_dct(img, block=8):
    """Compute 8×8 block DCT magnitudes for a grayscale image."""
    arr = np.array(img.convert("L"), dtype=np.float32)
    h, w = arr.shape

    # ensure divisible by block size
    h = h - (h % block)
    w = w - (w % block)
    arr = arr[:h, :w]

    coeffs = []

    for i in range(0, h, block):
        for j in range(0, w, block):
            patch = arr[i:i+block, j:j+block]
            d = dct(dct(patch.T, norm='ortho').T, norm='ortho')
            coeffs.append(np.abs(d))

    coeffs = np.stack(coeffs)  # shape: (num_blocks, 8, 8)
    return coeffs

def process_folder(folder):
    all_coeffs = []

    for fname in tqdm(os.listdir(folder), desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        c = block_dct(img)
        all_coeffs.append(c.mean(axis=0))  # average over blocks

    return np.stack(all_coeffs)  # shape: (num_images, 8, 8)

real_dct = process_folder(real_dir)
fake_dct = process_folder(fake_dir)

# average over images
real_mean = real_dct.mean(axis=0).flatten()
fake_mean = fake_dct.mean(axis=0).flatten()

plt.figure(figsize=(10,6))
plt.plot(real_mean, label="Real", linewidth=2)
plt.plot(fake_mean, label="Fake", linewidth=2)
plt.title("Average Log DCT Coefficient Magnitudes (Real vs Fake)")
plt.xlabel("Coefficient Index (0–63)")
plt.ylabel("Magnitude")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing dataset_3_cleaned/real: 100%|██████████| 26444/26444 [08:33<00:00, 51.48it/s]
# Processing dataset_3_cleaned/fake: 100%|██████████| 155802/155802 [51:28<00:00, 50.44it/s]

# %%
import os
import numpy as np
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
from scipy.fftpack import dct

real_dir = "test_dataset/real"
fake_dir = "test_dataset/fake"

def block_dct(img, block=8):
    """Compute 8×8 block DCT magnitudes for a grayscale image."""
    arr = np.array(img.convert("L"), dtype=np.float32)
    h, w = arr.shape

    # ensure divisible by block size
    h = h - (h % block)
    w = w - (w % block)
    arr = arr[:h, :w]

    coeffs = []

    for i in range(0, h, block):
        for j in range(0, w, block):
            patch = arr[i:i+block, j:j+block]
            d = dct(dct(patch.T, norm='ortho').T, norm='ortho')
            coeffs.append(np.abs(d))

    coeffs = np.stack(coeffs)  # shape: (num_blocks, 8, 8)
    return coeffs

def process_folder(folder):
    all_coeffs = []

    for fname in tqdm(os.listdir(folder), desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        c = block_dct(img)
        all_coeffs.append(c.mean(axis=0))  # average over blocks

    return np.stack(all_coeffs)  # shape: (num_images, 8, 8)

real_dct = process_folder(real_dir)
fake_dct = process_folder(fake_dir)

# average over images
real_mean = real_dct.mean(axis=0).flatten()
fake_mean = fake_dct.mean(axis=0).flatten()

plt.figure(figsize=(10,6))
plt.plot(real_mean, label="Real", linewidth=2)
plt.plot(fake_mean, label="Fake", linewidth=2)
plt.title("Average Log DCT Coefficient Magnitudes (Real vs Fake)")
plt.xlabel("Coefficient Index (0–63)")
plt.ylabel("Magnitude")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Processing test_dataset/real: 100%|██████████| 5890/5890 [01:54<00:00, 51.57it/s]
# Processing test_dataset/fake: 100%|██████████| 12234/12234 [04:04<00:00, 49.98it/s]

# %%
import os
import numpy as np
from PIL import Image
from scipy.signal import convolve2d
from tqdm import tqdm

# --- SRM-Lite high-pass filters ---
SRM_FILTERS = [
    np.array([[0, 0, 0],
              [0, 1, -1],
              [0, 0, 0]], dtype=np.float32),

    np.array([[0, 0, 0],
              [0, 1, 0],
              [0, -1, 0]], dtype=np.float32),

    np.array([[0, 0, 0],
              [0, 1, 0],
              [0, 0, -1]], dtype=np.float32)
]

def srm_residual_energy(img):
    """Compute SRM-lite residual energy for a grayscale image."""
    gray = np.array(img.convert("L"), dtype=np.float32)

    energies = []
    for f in SRM_FILTERS:
        r = convolve2d(gray, f, mode="same", boundary="symm")
        energies.append(np.mean(np.abs(r)))

    return np.mean(energies)

def process_folder(folder):
    values = []
    files = os.listdir(folder)

    for fname in tqdm(files, desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        val = srm_residual_energy(img)
        values.append(val)

    return np.array(values)

real_vals = process_folder("dataset_1_cleaned/real")
fake_vals = process_folder("dataset_1_cleaned/fake")

print("Real mean:", real_vals.mean())
print("Fake mean:", fake_vals.mean())

import matplotlib.pyplot as plt

plt.hist(real_vals, bins=50, alpha=0.5, label="Real", density=True)
plt.hist(fake_vals, bins=50, alpha=0.5, label="Fake", density=True)
plt.legend()
plt.title("SRM Residual Energy Distribution")
plt.show()
# Out:
# Processing dataset_1_cleaned/real: 100%|██████████| 28475/28475 [03:24<00:00, 138.95it/s]
# Processing dataset_1_cleaned/fake: 100%|██████████| 28596/28596 [03:59<00:00, 119.64it/s]
# Real mean: 6.8008933
# Fake mean: 7.043321

# %%
import os
import numpy as np
from PIL import Image
from scipy.signal import convolve2d
from tqdm import tqdm

# --- SRM-Lite high-pass filters ---
SRM_FILTERS = [
    np.array([[0, 0, 0],
              [0, 1, -1],
              [0, 0, 0]], dtype=np.float32),

    np.array([[0, 0, 0],
              [0, 1, 0],
              [0, -1, 0]], dtype=np.float32),

    np.array([[0, 0, 0],
              [0, 1, 0],
              [0, 0, -1]], dtype=np.float32)
]

def srm_residual_energy(img):
    """Compute SRM-lite residual energy for a grayscale image."""
    gray = np.array(img.convert("L"), dtype=np.float32)

    energies = []
    for f in SRM_FILTERS:
        r = convolve2d(gray, f, mode="same", boundary="symm")
        energies.append(np.mean(np.abs(r)))

    return np.mean(energies)

def process_folder(folder):
    values = []
    files = os.listdir(folder)

    for fname in tqdm(files, desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        val = srm_residual_energy(img)
        values.append(val)

    return np.array(values)

real_vals = process_folder("dataset_2_cleaned/real")
fake_vals = process_folder("dataset_2_cleaned/fake")

print("Real mean:", real_vals.mean())
print("Fake mean:", fake_vals.mean())

import matplotlib.pyplot as plt

plt.hist(real_vals, bins=50, alpha=0.5, label="Real", density=True)
plt.hist(fake_vals, bins=50, alpha=0.5, label="Fake", density=True)
plt.legend()
plt.title("SRM Residual Energy Distribution")
plt.show()
# Out:
# Processing dataset_2_cleaned/real: 100%|██████████| 60192/60192 [07:03<00:00, 142.12it/s]
# Processing dataset_2_cleaned/fake: 100%|██████████| 51991/51991 [05:54<00:00, 146.85it/s]
# Real mean: 7.219295
# Fake mean: 7.243254

# %%
import os
import numpy as np
from PIL import Image
from scipy.signal import convolve2d
from tqdm import tqdm

# --- SRM-Lite high-pass filters ---
SRM_FILTERS = [
    np.array([[0, 0, 0],
              [0, 1, -1],
              [0, 0, 0]], dtype=np.float32),

    np.array([[0, 0, 0],
              [0, 1, 0],
              [0, -1, 0]], dtype=np.float32),

    np.array([[0, 0, 0],
              [0, 1, 0],
              [0, 0, -1]], dtype=np.float32)
]

def srm_residual_energy(img):
    """Compute SRM-lite residual energy for a grayscale image."""
    gray = np.array(img.convert("L"), dtype=np.float32)

    energies = []
    for f in SRM_FILTERS:
        r = convolve2d(gray, f, mode="same", boundary="symm")
        energies.append(np.mean(np.abs(r)))

    return np.mean(energies)

def process_folder(folder):
    values = []
    files = os.listdir(folder)

    for fname in tqdm(files, desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        val = srm_residual_energy(img)
        values.append(val)

    return np.array(values)

real_vals = process_folder("dataset_3_cleaned/real")
fake_vals = process_folder("dataset_3_cleaned/fake")

print("Real mean:", real_vals.mean())
print("Fake mean:", fake_vals.mean())

import matplotlib.pyplot as plt

plt.hist(real_vals, bins=50, alpha=0.5, label="Real", density=True)
plt.hist(fake_vals, bins=50, alpha=0.5, label="Fake", density=True)
plt.legend()
plt.title("SRM Residual Energy Distribution")
plt.show()
# Out:
# Processing dataset_3_cleaned/real: 100%|██████████| 26444/26444 [03:09<00:00, 139.37it/s]
# Processing dataset_3_cleaned/fake: 100%|██████████| 155802/155802 [18:13<00:00, 142.43it/s]
# Real mean: 3.898105
# Fake mean: 3.7691224

# %%
import os
import numpy as np
from PIL import Image
from scipy.signal import convolve2d
from tqdm import tqdm

# --- SRM-Lite high-pass filters ---
SRM_FILTERS = [
    np.array([[0, 0, 0],
              [0, 1, -1],
              [0, 0, 0]], dtype=np.float32),

    np.array([[0, 0, 0],
              [0, 1, 0],
              [0, -1, 0]], dtype=np.float32),

    np.array([[0, 0, 0],
              [0, 1, 0],
              [0, 0, -1]], dtype=np.float32)
]

def srm_residual_energy(img):
    """Compute SRM-lite residual energy for a grayscale image."""
    gray = np.array(img.convert("L"), dtype=np.float32)

    energies = []
    for f in SRM_FILTERS:
        r = convolve2d(gray, f, mode="same", boundary="symm")
        energies.append(np.mean(np.abs(r)))

    return np.mean(energies)

def process_folder(folder):
    values = []
    files = os.listdir(folder)

    for fname in tqdm(files, desc=f"Processing {folder}"):
        path = os.path.join(folder, fname)
        try:
            img = Image.open(path)
        except:
            continue

        val = srm_residual_energy(img)
        values.append(val)

    return np.array(values)

real_vals = process_folder("test_dataset/real")
fake_vals = process_folder("test_dataset/fake")

print("Real mean:", real_vals.mean())
print("Fake mean:", fake_vals.mean())

import matplotlib.pyplot as plt

plt.hist(real_vals, bins=50, alpha=0.5, label="Real", density=True)
plt.hist(fake_vals, bins=50, alpha=0.5, label="Fake", density=True)
plt.legend()
plt.title("SRM Residual Energy Distribution")
plt.show()
# Out:
# Processing test_dataset/real: 100%|██████████| 5890/5890 [00:39<00:00, 149.95it/s]
# Processing test_dataset/fake: 100%|██████████| 12234/12234 [01:20<00:00, 152.82it/s]
# Real mean: 5.924875
# Fake mean: 5.347029
